# %%
import matplotlib.pyplot as plt

# %%
 x = [1, 2, 3, 4, 5]
 y = [1, 2, 3, 4, 5]
 z = [5, 4,3,2,1]

plt.plot(x, y)
plt.plot(x,z)
plt.title("Test plot")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(["This is y", "This is z"])
plt.show()

# %%
plt.scatter(x, y)
plt.show()
